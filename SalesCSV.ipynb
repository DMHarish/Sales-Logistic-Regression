# %%
# import csv

# %%
# with open('Sales.csv', 'r') as n:
#     csv_read = csv.reader(n)
#     for i in csv_read:
#         print(i)
# Out:
# ['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority', 'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']
# ['Middle East and North Africa', 'Libya', 'Cosmetics', 'Offline', 'M', '10/18/2014', '686800706', '10/31/2014', '8446', '437.20', '263.33', '3692591.20', '2224085.18', '1468506.02']
# ['North America', 'Canada', 'Vegetables', 'Online', 'M', '11/7/2011', '185941302', '12/8/2011', '3018', '154.06', '90.93', '464953.08', '274426.74', '190526.34']
# ['Middle East and North Africa', 'Libya', 'Baby Food', 'Offline', 'C', '10/31/2016', '246222341', '12/9/2016', '1517', '255.28', '159.42', '387259.76', '241840.14', '145419.62']
# ['Asia', 'Japan', 'Cereal', 'Offline', 'C', '4/10/2010', '161442649', '5/12/2010', '3322', '205.70', '117.11', '683335.40', '389039.42', '294295.98']
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv('Sales.csv')

# %%
data.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
data.describe()
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit
# count  1.000000e+03  1.000000e+03
# mean   9.361192e+05  3.912026e+05
# std    1.162571e+06  3.836402e+05
# min    1.416750e+03  5.326100e+02
# 25%    1.649319e+05  9.837612e+04
# 50%    4.647261e+05  2.772260e+05
# 75%    1.141750e+06  5.484568e+05
# ...

# %%
data.shape
# Out:
# (1000, 14)

# %%
data.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
#type(data.Total Price)

# %%
data['Unit Price'].isnull().sum()
# Out:
# 0

# %%
data.dropna()
# Out:
#                                 Region                           Country  \
# 0         Middle East and North Africa                             Libya
# 1                        North America                            Canada
# 2         Middle East and North Africa                             Libya
# 3                                 Asia                             Japan
# 4                   Sub-Saharan Africa                              Chad
# 5                               Europe                           Armenia
# 6                   Sub-Saharan Africa                           Eritrea
# 7                               Europe                        Montenegro
# 8    Central America and the Caribbean                           Jamaica
# 9                Australia and Oceania                              Fiji
# 10                  Sub-Saharan Africa                              Togo
# 11                              Europe                        Montenegro
# ...

# %%
data.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(['Units Sold','Units Price', 'Unit Cost','Total Cost','Total Price','Total Profit'])

# %%
data.plot()

# %%
data ['Total Cost']. plot(style = 'g. ')

# %%
plt.figure(figsize=(20,10))
plt.title('Sales Report', fontsize = 25, color= 'g')
plt.xlabel('Number',fontsize = 20)
plt.ylabel('Number',fontsize = 20)
data['Total Profit'].plot(style = 'b')
plt.show()

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
data.describe()
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit
# count  1.000000e+03  1.000000e+03
# mean   9.361192e+05  3.912026e+05
# std    1.162571e+06  3.836402e+05
# min    1.416750e+03  5.326100e+02
# 25%    1.649319e+05  9.837612e+04
# 50%    4.647261e+05  2.772260e+05
# 75%    1.141750e+06  5.484568e+05
# ...

# %%
x = data.drop(['Units Sold','Total Profit'],axis=1)
y = data['Units Sold']

# %%
x = data[['Units Sold','Unit Price','Unit Cost','Total Revenue','Total Profit']]

# %%
import pandas as pd

# %%
#data['new_date'] = pd.to_numeric(data.Order Date)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.3)

# %%
x_train.shape
# Out:
# (700, 5)

# %%
y_train.shape
# Out:
# (700,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# C:\Users\Dmhar\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Dmhar\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
a = LR.predict(x_test)

# %%
b = LR.score(x_test,y_test)

# %%
print(b)
# Out:
# 0.0
